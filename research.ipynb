# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

import sys
import os

# プロジェクトのルートディレクトリ（srcの親階層）をパスに追加
#project_root = os.path.abspath("..") # ノートブックがルート直下にある場合
#if project_root not in sys.path:
#    sys.path.append(project_root)
    
a=os.getcwd()
print(a)
# 自作モジュールのインポート
from src.core.simulator import RaceSimulator

# テスト開始
sim = RaceSimulator()
# Out:
# [2026-04-03 22:39:39] INFO - Simulator - 初期化中...
# /home/yaya/Documents/Works/App/NKSimulator

# %% [markdown]
# # Simulatorの個別テスト

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.constants.course_master import CourseSpec, NAME_TO_COURSE

name = "大井"
NAME_TO_COURSE.get(name, "")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# CourseSpec(name='大井', is_jra=False, is_excluded=False, track_width=25, corner_penalty=0.15, furf_friction=0.01, surface_friction=0.05)

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.constants.course_master import COURSE_MASTER, NAME_TO_CODE

b = "大井"
a = NAME_TO_CODE[b]
print(a)
# Out:
# 44

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.constants.race_master import TrackCondition, TrackWeather

a = 0.1
res = TrackCondition.from_str(a)
res2 = TrackWeather.from_str(a)
res, res2
# Out:
# (<TrackCondition.ANY: '未'>, <TrackWeather.ANY: '未'>)

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.core.simulator import RaceSimulator

sim = RaceSimulator()
date = "20260324"
courses = ["大井",]
race_numbers = [1,]
sim._prepare_races(date, courses, race_numbers)
# Out:
# [RaceInfo(race_id='20260324大井01', course_name='大井', race_name='C3五六', race_num=np.int64(1), distance=np.int64(1600), surface='ダ', condition=<TrackCondition.GOOD: '良'>, weather=<TrackWeather.SUNNY: '晴'>, track_width=25, corner_penalty=0.15, surface_friction=0.05, sections=[TrackSection(type=<SectionType.STRAIGHT: '直線'>, distance=200, start_at=0, name=<SectionName.STARTING: 'starting straight'>, slope=0.0), TrackSection(type=<SectionType.CURVE: 'コーナー'>, distance=300, start_at=200, name=<SectionName.TURN_1ST_2ND: '1st and 2nd turns'>, slope=0.0), TrackSection(type=<SectionType.STRAIGHT: '直線'>, distance=400, start_at=500, name=<SectionName.BACKSTRETCH: 'back stretch'>, slope=0.0), TrackSection(type=<SectionType.CURVE: 'コーナー'>, distance=400, start_at=900, name=<SectionName.TURN_3RD_4TH: '3rd and 4th turns'>, slope=0.0), TrackSection(type=<SectionType.STRAIGHT: '直線'>, distance=300, start_at=1300, name=<SectionName.HOMESTRETCH: 'homa stretch'>, slope=0.0)], horses=[HorseInfo(horse_id=202110
# ...
