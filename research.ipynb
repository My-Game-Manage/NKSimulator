# %% [markdown]
# # Simulation のための準備（個別テスト）

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2
    
import pandas as pd

# Provider のテスト
from src.services.provider import RaceDataProvider

date = "20260324"
courses = ["大井"]
race_nums = [1]

provider = RaceDataProvider()
race_data_list = provider.create_race_raw_data_list(date, courses, race_nums)

print(race_data_list)
# Out:
# [RaceRawData(race_id='202603244401', course='大井', race_num=np.int64(1), entries=          date course weather  race_number race_name surface  distance  \
# 0   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 1   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 2   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 3   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 4   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 5   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 6   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 7   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 8   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 9   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 10  2026/03/24     大井       晴            1      C3五六       ダ      1600
# 11  2026/03/24     大井       晴            1      C3五六       ダ      1600
# 12  2026/03/24     大井       晴            1      C3五六       ダ      1600
#
#    track_condition  num_horses  bracket_number  ...    father_name  \
# 0                良          13               1  ...          ベーカバド
# 1                良          13               2  ...         ラブリーデイ
# 2                良          13               3  ...       ロージズインメイ
# 3                良          13               4  ...  デクラレーションオブウォー
# 4                良          13               4  ...       タニノギムレット
# 5                良          13               5  ...     シニスターミニスター
# 6                良          13               5  ...            パイロ
# 7                良          13               6  ...  デクラレーションオブウォー
# 8                良          13               6  ...    マインドユアビスケッツ
# 9                良          13               7  ...        トゥザワールド
# 10               良          13               7  ...        コパノリッキー
# 11               良          13               8  ...         ラブリーデイ
# 12               良          13               8  ...             ラニ
#
#        mother_name sex age weight_carried  jockey  stable horse_weight  \
# 0          Behkara   牡   5           56.0    仲原大生  大井佐々木洋          457
# 1        ポップコーンジャズ   牡   5           55.0    中山遥人  大井須田和伸          462
# 2    Tell a Secret   牝   7           54.0    石川駿介  大井岡野尚光          491
# 3       Tempo West   牝   5           54.0    矢野貴之  大井藤田輝信          510
# 4         タニノクリスタル   セ   7           55.0    谷内貫太  大井久保杉隆          479
# 5   Sweet Minister   牡   5           56.0     鷹見陸   大井澤佳宏          485
# 6      Wild Vision   牡   7           56.0     吉井章   大井市村誠          475
# 7       Tempo West   牝   4           54.0    横川怜央  大井久保杉隆          461
# 8         Jazzmane   牡   5           56.0    瀬川将輝  大井栗田裕光          533
# 9        トゥザヴィクトリー   牡   6           53.0    杉山海波  大井井上弘之          451
# 10         コパノニキータ   セ   7           56.0     野畑凌   大井鷹見浩          479
# 11       ポップコーンジャズ   牡   6           56.0    菅原涼太  大井荒井朋弘          451
# 12       ヘヴンリーロマンス   牝   7           54.0    澤田龍哉  大井田中正人          453
#
#    weight_diff    horse_id
# 0           -2  2021103462
# 1           -6  2021104202
# 2           -7  2019101304
# 3            2  2021102429
# 4           -4  2019109083
# 5           -3  2021102897
# 6           -1  2019101552
# 7           -1  2022109083
# 8           -3  2021106391
# 9            1  2020106112
# 10          -2  2019102067
# 11          -6  2020102455
# 12          -8  2019109031
#
# [13 rows x 22 columns], histories=        horse_id horse_name        date course weather  race_number  \
# 0     2021103462     ブッコワース  2026/03/24     大井       晴            1
# 1     2021103462     ブッコワース  2026/03/10     大井       雨            1
# 2     2021103462     ブッコワース  2025/11/10     大井       晴            2
# 3     2021103462     ブッコワース  2025/10/20     大井       曇            6
# 4     2021103462     ブッコワース  2025/10/05     大井       晴            4
# ...          ...        ...         ...    ...     ...          ...
# 3365  2022105174      フェアゴー  2025/06/14   3東京3       曇            7
# 3366  2022105174      フェアゴー  2025/05/17   2東京7       雨            2
# 3367  2022105174      フェアゴー  2025/03/23   2中京4       晴            3
# 3368  2022105174      フェアゴー  2025/02/23   1東京8       晴            1
# 3369  2022105174      フェアゴー  2024/12/07   4中京3       曇            5
#
#            race_name  num_horses  bracket_number  horse_number  ...  distance  \
# 0               C3五六          13               1             1  ...    1600.0
# 1               C3五六          14               4             6  ...    1600.0
# 2             C21819          13               7            11  ...    1600.0
# 3     住まいのみやこすぎな(C2)          10               7             8  ...    1600.0
# 4      ゴッドファーザー賞(C2)           8               4             4  ...    1600.0
# ...              ...         ...             ...           ...  ...       ...
# 3365           3歳未勝利          16               5             9  ...    1600.0
# 3366           3歳未勝利          16               8            16  ...    1600.0
# 3367           3歳未勝利          16               4             7  ...    1400.0
# 3368           3歳未勝利          16               5             9  ...    1400.0
# 3369            2歳新馬          16               4             8  ...    1400.0
#
#       track_condition   time margin  passing_order last_3f  horse_weight  \
# 0                   良  105.8    0.5        7-7-8-8    39.8         457.0
# 1                   稍  107.8    1.5        5-5-5-6    41.8         459.0
# 2                   稍  106.7    4.2        6-7-7-9    43.7         457.0
# 3                   稍  105.6    1.5        2-2-3-3    40.6         454.0
# 4                   良  104.3    0.8        5-5-5-5    40.9         452.0
# ...               ...    ...    ...            ...     ...           ...
# 3365                良   98.0    0.2            5-4    37.0         500.0
# 3366                稍   98.9    0.2            5-5    37.2         508.0
# 3367                良   86.2    0.8            9-9    38.0         500.0
# 3368                良   86.8    0.4          15-14    36.6         506.0
# 3369                良   87.2    2.0          16-16    36.6         502.0
#
#      weight_diff  winner_name  prize
# 0           -2.0    ワールドフォンテン    NaN
# 1            2.0    ワールドフォンテン    NaN
# 2            3.0     テンシノトリブン    NaN
# 3            2.0     ドラゴンバスター   10.0
# 4            0.0      フェアクラウド   10.0
# ...          ...          ...    ...
# 3365        -8.0    ブラーブデシジョン  220.0
# 3366         8.0      クリオシダード  220.0
# 3367        -6.0    ハウリングウィンド   84.0
# 3368         4.0    プライベートアイズ   84.0
# 3369         0.0         トゥロン    NaN
#
# [3370 rows x 26 columns])]

# %%
# RaceInfo 作成
from src.services.race_factory import RaceInfoFactory

raw_data = race_data_list[0]

factory = RaceInfoFactory()
race_info =factory.create_race_info(raw_data)

print(pd.DataFrame([race_info]))
# Out:
#         race_id course_name race_name  race_num horses
# 0  202603244401          大井      C3五六         1     {}

# %%
# RaceParam 作成

race_param = factory.create_race_param(raw_data)

print(pd.DataFrame([race_param]))
# Out:
#         race_id  distance surface            condition             weather  \
# 0  202603244401      1600       ダ  TrackCondition.GOOD  TrackWeather.SUNNY
#
#    track_width  corner_penalty  surface_friction  \
# 0           25            0.15              0.05
#
#                                             sections            checkpoints  \
# 0  [{'type': SectionType.STRAIGHT, 'distance': 20...  [200, 500, 900, 1300]
#
#   horses
# 0     {}

# %%
# HorseInfo 作成

from src.services.horse_factory import HorseFactory

h_factory = HorseFactory()

horse_infos = h_factory.create_horse_infos(raw_data.entries)

print(pd.Series(horse_infos))
for h_id, h_info in horse_infos.items():
    print(pd.DataFrame([h_info]))
# Out:
# 2021103462    HorseInfo(horse_id=2021103462, name='ブッコワース', ...
# 2021104202    HorseInfo(horse_id=2021104202, name='ブラントンアロー'...
# 2019101304    HorseInfo(horse_id=2019101304, name='イケノギャルチャン...
# 2021102429    HorseInfo(horse_id=2021102429, name='ローゼンナイツ',...
# 2019109083    HorseInfo(horse_id=2019109083, name='ミンナノブンモ',...
# 2021102897    HorseInfo(horse_id=2021102897, name='アイアムイブシギン...
# 2019101552    HorseInfo(horse_id=2019101552, name='ゴッドモード', ...
# 2022109083    HorseInfo(horse_id=2022109083, name='アイトカコイトカ'...
# 2021106391    HorseInfo(horse_id=2021106391, name='オリリオ', br...
# 2020106112    HorseInfo(horse_id=2020106112, name='ワールドフォンテン...
# 2019102067    HorseInfo(horse_id=2019102067, name='ラインストライカー...
# 2020102455    HorseInfo(horse_id=2020102455, name='ラブリーヨシノ',...
# 2019109031    HorseInfo(horse_id=2019109031, name='フローラルロマンス...
# dtype: object
#      horse_id    name  bracket_num  horse_num
# 0  2021103462  ブッコワース            1          1
#      horse_id      name  bracket_num  horse_num
# 0  2021104202  ブラントンアロー            2          2
#      horse_id       name  bracket_num  horse_num
# 0  2019101304  イケノギャルチャン            3          3
#      horse_id     name  bracket_num  horse_num
# 0  2021102429  ローゼンナイツ            4          4
#      horse_id     name  bracket_num  horse_num
# 0  2019109083  ミンナノブンモ            4          5
#      horse_id       name  bracket_num  horse_num
# 0  2021102897  アイアムイブシギン            5          6
#      horse_id    name  bracket_num  horse_num
# 0  2019101552  ゴッドモード            5          7
#      horse_id      name  bracket_num  horse_num
# 0  2022109083  アイトカコイトカ            6          8
#      horse_id  name  bracket_num  horse_num
# 0  2021106391  オリリオ            6          9
#      horse_id       name  bracket_num  horse_num
# 0  2020106112  ワールドフォンテン            7         10
#      horse_id       name  bracket_num  horse_num
# 0  2019102067  ラインストライカー            7         11
#      horse_id     name  bracket_num  horse_num
# 0  2020102455  ラブリーヨシノ            8         12
#      horse_id       name  bracket_num  horse_num
# 0  2019109031  フローラルロマンス            8         13

# %%
# HorseParam の作成

horse_params = h_factory.create_horse_params(raw_data.entries, raw_data.histories, race_param.distance)

print(pd.Series(horse_params))
for h_id, h_param in horse_params.items():
    print(pd.DataFrame([h_param]))
# Out:
# 2021103462    HorseParam(horse_id=2021103462, max_speed=np.f...
# 2021104202    HorseParam(horse_id=2021104202, max_speed=np.f...
# 2019101304    HorseParam(horse_id=2019101304, max_speed=np.f...
# 2021102429    HorseParam(horse_id=2021102429, max_speed=np.f...
# 2019109083    HorseParam(horse_id=2019109083, max_speed=np.f...
# 2021102897    HorseParam(horse_id=2021102897, max_speed=np.f...
# 2019101552    HorseParam(horse_id=2019101552, max_speed=np.f...
# 2022109083    HorseParam(horse_id=2022109083, max_speed=np.f...
# 2021106391    HorseParam(horse_id=2021106391, max_speed=np.f...
# 2020106112    HorseParam(horse_id=2020106112, max_speed=np.f...
# 2019102067    HorseParam(horse_id=2019102067, max_speed=np.f...
# 2020102455    HorseParam(horse_id=2020102455, max_speed=np.f...
# 2019109031    HorseParam(horse_id=2019109031, max_speed=np.f...
# dtype: object
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2021103462  15.831208      0.920667    2145.596774            0.993271
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0             0.4875       0.620553  StrategyEnum.BETWEEN              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2021104202  16.027562      0.913375      2146.5625            0.989565
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0              0.516       0.686392  StrategyEnum.BETWEEN              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2019101304  15.905704      0.937254    2404.429577            0.985636
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.537313       0.423043  StrategyEnum.PUSHING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2021102429    16.0389         1.015         2409.2            0.980904
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.466667       0.812363  StrategyEnum.LEADING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2019109083  15.914876       0.90325    2640.196721            0.995737
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.474074       0.802726  StrategyEnum.LEADING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2021102897  16.136443      0.956167    2281.916667             0.99177
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.552941       0.663652  StrategyEnum.BETWEEN              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2019101552  15.848202      0.961979    2639.364583            0.980796
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.513333       0.355556  StrategyEnum.PUSHING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2022109083  15.965506      0.964474    2629.342105            0.979164
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0                0.5       0.487199  StrategyEnum.PUSHING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2021106391  15.551181      0.889423    2664.538462            0.992326
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.468182       0.442484  StrategyEnum.PUSHING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2020106112  15.716688       0.94875     2142.09375            0.987422
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.493333       0.949069  StrategyEnum.LEADING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2019102067  15.795717        0.9265         2643.0            0.983969
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.576087       0.580423  StrategyEnum.BETWEEN              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2020102455   16.13722        0.9132        2140.12            0.995345
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.422581       0.829975  StrategyEnum.LEADING              600.0
#      horse_id  max_speed  acceleration  total_stamina  stamina_waste_rate  \
# 0  2019109031  16.123205         0.915    2629.190476             0.99427
#
#    cornering_ability  gate_reaction              strategy  target_spurt_dist
# 0           0.466667       0.826775  StrategyEnum.LEADING              600.0

# %%
# HorseState の作成

horse_states = h_factory.create_horse_states(horse_infos, horse_params)

print(pd.Series(horse_states))
for h_id, h_state in horse_states.items():
    print(pd.DataFrame([h_state]))
# Out:
# 2021103462    HorseState(horse_id=2021103462, step=0, elapse...
# 2021104202    HorseState(horse_id=2021104202, step=0, elapse...
# 2019101304    HorseState(horse_id=2019101304, step=0, elapse...
# 2021102429    HorseState(horse_id=2021102429, step=0, elapse...
# 2019109083    HorseState(horse_id=2019109083, step=0, elapse...
# 2021102897    HorseState(horse_id=2021102897, step=0, elapse...
# 2019101552    HorseState(horse_id=2019101552, step=0, elapse...
# 2022109083    HorseState(horse_id=2022109083, step=0, elapse...
# 2021106391    HorseState(horse_id=2021106391, step=0, elapse...
# 2020106112    HorseState(horse_id=2020106112, step=0, elapse...
# 2019102067    HorseState(horse_id=2019102067, step=0, elapse...
# 2020102455    HorseState(horse_id=2020102455, step=0, elapse...
# 2019109031    HorseState(horse_id=2019109031, step=0, elapse...
# dtype: object
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2021103462     0           0.0       0.0       0.0        15.831208
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2145.596774        False         False  SectionType.STRAIGHT     1.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2021104202     0           0.0       0.0       0.0        16.027562
#
#      stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2146.5625        False         False  SectionType.STRAIGHT     2.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2019101304     0           0.0       0.0       0.0        15.905704
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2404.429577        False         False  SectionType.STRAIGHT     3.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2021102429     0           0.0       0.0       0.0          16.0389
#
#    stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0   2409.2        False         False  SectionType.STRAIGHT     4.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2019109083     0           0.0       0.0       0.0        15.914876
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2640.196721        False         False  SectionType.STRAIGHT     5.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2021102897     0           0.0       0.0       0.0        16.136443
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2281.916667        False         False  SectionType.STRAIGHT     6.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2019101552     0           0.0       0.0       0.0        15.848202
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2639.364583        False         False  SectionType.STRAIGHT     7.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2022109083     0           0.0       0.0       0.0        15.965506
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2629.342105        False         False  SectionType.STRAIGHT     8.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2021106391     0           0.0       0.0       0.0        15.551181
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2664.538462        False         False  SectionType.STRAIGHT     9.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2020106112     0           0.0       0.0       0.0        15.716688
#
#       stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2142.09375        False         False  SectionType.STRAIGHT    10.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2019102067     0           0.0       0.0       0.0        15.795717
#
#    stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0   2643.0        False         False  SectionType.STRAIGHT    11.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2020102455     0           0.0       0.0       0.0         16.13722
#
#    stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2140.12        False         False  SectionType.STRAIGHT    12.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None
#      horse_id  step  elapsed_time  distance  velocity  target_velocity  \
# 0  2019109031     0           0.0       0.0       0.0        16.123205
#
#        stamina  is_spurting  is_exhausted          section_name  lane_p  \
# 0  2629.190476        False         False  SectionType.STRAIGHT    13.0
#
#    is_blocked  is_finished finish_time
# 0       False        False        None

# %% [markdown]
# # Simulatorテスト

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

# レースデータ準備

from src.core.simulator import RaceSimulator

sim = RaceSimulator()

date = "20260324"
courses = ["大井"]
race_numbers = [1]

r_list = sim._prepare_races(date, courses, race_numbers)
print(r_list)
# Out:
# [RaceDataSet(race_id='202603244401', info=RaceInfo(race_id='202603244401', course_name='大井', race_name='C3五六', race_num=np.int64(1), horses={2021103462: HorseInfo(horse_id=2021103462, name='ブッコワース', bracket_num=1, horse_num=1), 2021104202: HorseInfo(horse_id=2021104202, name='ブラントンアロー', bracket_num=2, horse_num=2), 2019101304: HorseInfo(horse_id=2019101304, name='イケノギャルチャン', bracket_num=3, horse_num=3), 2021102429: HorseInfo(horse_id=2021102429, name='ローゼンナイツ', bracket_num=4, horse_num=4), 2019109083: HorseInfo(horse_id=2019109083, name='ミンナノブンモ', bracket_num=4, horse_num=5), 2021102897: HorseInfo(horse_id=2021102897, name='アイアムイブシギン', bracket_num=5, horse_num=6), 2019101552: HorseInfo(horse_id=2019101552, name='ゴッドモード', bracket_num=5, horse_num=7), 2022109083: HorseInfo(horse_id=2022109083, name='アイトカコイトカ', bracket_num=6, horse_num=8), 2021106391: HorseInfo(horse_id=2021106391, name='オリリオ', bracket_num=6, horse_num=9), 2020106112: HorseInfo(horse_id=2020106112, name='ワールドフォンテン', bracket_num=7, horse_num=10), 2019102067: HorseInfo(horse_id=2019102067, name='ラインストライカー', bracket_num=7, horse_num=11), 2020102455: HorseInfo(horse_id=2020102455, name='ラブリーヨシノ', bracket_num=8, horse_num=12), 2019109031: HorseInfo(horse_id=2019109031, name='フローラルロマンス', bracket_num=8, horse_num=13)}), param=RaceParam(race_id='202603244401', distance=np.int64(1600), surface='ダ', condition=<TrackCondition.GOOD: '良'>, weather=<TrackWeather.SUNNY: '晴'>, track_width=25, corner_penalty=0.15, surface_friction=0.05, sections=[TrackSection(type=<SectionType.STRAIGHT: '直線'>, distance=200, start_at=0, name=<SectionName.STARTING: 'starting straight'>, slope=0.0), TrackSection(type=<SectionType.CURVE: 'コーナー'>, distance=300, start_at=200, name=<SectionName.TURN_1ST_2ND: '1st and 2nd turns'>, slope=0.0), TrackSection(type=<SectionType.STRAIGHT: '直線'>, distance=400, start_at=500, name=<SectionName.BACKSTRETCH: 'back stretch'>, slope=0.0), TrackSection(type=<SectionType.CURVE: 'コーナー'>, distance=400, start_at=900, name=<SectionName.TURN_3RD_4TH: '3rd and 4th turns'>, slope=0.0), TrackSection(type=<SectionType.STRAIGHT: '直線'>, distance=300, start_at=1300, name=<SectionName.HOMESTRETCH: 'homa stretch'>, slope=0.0)], checkpoints=[200, 500, 900, 1300], horses={2021103462: HorseParam(horse_id=2021103462, max_speed=np.float64(15.8312080406234), acceleration=np.float64(0.9206666666666667), total_stamina=np.float64(2145.5967741935483), stamina_waste_rate=np.float64(0.9932708758540368), cornering_ability=0.4875, gate_reaction=np.float64(0.6205525030525031), strategy=<StrategyEnum.BETWEEN: '差し'>, target_spurt_dist=600.0), 2021104202: HorseParam(horse_id=2021104202, max_speed=np.float64(16.02756182797734), acceleration=np.float64(0.9133749999999999), total_stamina=np.float64(2146.5625), stamina_waste_rate=np.float64(0.989564739529336), cornering_ability=0.516, gate_reaction=np.float64(0.6863916985791986), strategy=<StrategyEnum.BETWEEN: '差し'>, target_spurt_dist=600.0), 2019101304: HorseParam(horse_id=2019101304, max_speed=np.float64(15.905704376457392), acceleration=np.float64(0.9372535211267603), total_stamina=np.float64(2404.429577464789), stamina_waste_rate=np.float64(0.985635957299791), cornering_ability=0.5373134328358209, gate_reaction=np.float64(0.42304286089497356), strategy=<StrategyEnum.PUSHING: '追込'>, target_spurt_dist=600.0), 2021102429: HorseParam(horse_id=2021102429, max_speed=np.float64(16.03890038589192), acceleration=np.float64(1.015), total_stamina=np.float64(2409.2), stamina_waste_rate=np.float64(0.9809044235691259), cornering_ability=0.4666666666666667, gate_reaction=np.float64(0.8123626373626374), strategy=<StrategyEnum.LEADING: '先行'>, target_spurt_dist=600.0), 2019109083: HorseParam(horse_id=2019109083, max_speed=np.float64(15.914875537412248), acceleration=np.float64(0.9032500000000002), total_stamina=np.float64(2640.1967213114754), stamina_waste_rate=np.float64(0.9957374373683152), cornering_ability=0.4740740740740741, gate_reaction=np.float64(0.8027263939 ...
