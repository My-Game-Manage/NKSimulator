# %% [markdown]
# # Simulation のための準備

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2
    
# Provider のテスト
from src.services.provider import RaceDataProvider

date = "20260324"
courses = ["大井"]
race_nums = [1]

provider = RaceDataProvider()
race_data_list = provider.create_race_raw_data_list(date, courses, race_nums)

#print(race_data_list)
# Out:
# [RaceRawData(race_id='202603244401', course='大井', race_num=np.int64(1), entries=          date course weather  race_number race_name surface  distance  \
# 0   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 1   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 2   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 3   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 4   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 5   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 6   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 7   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 8   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 9   2026/03/24     大井       晴            1      C3五六       ダ      1600
# 10  2026/03/24     大井       晴            1      C3五六       ダ      1600
# 11  2026/03/24     大井       晴            1      C3五六       ダ      1600
# 12  2026/03/24     大井       晴            1      C3五六       ダ      1600
#
#    track_condition  num_horses  bracket_number  ...    father_name  \
# 0                良          13               1  ...          ベーカバド
# 1                良          13               2  ...         ラブリーデイ
# 2                良          13               3  ...       ロージズインメイ
# 3                良          13               4  ...  デクラレーションオブウォー
# 4                良          13               4  ...       タニノギムレット
# 5                良          13               5  ...     シニスターミニスター
# 6                良          13               5  ...            パイロ
# 7                良          13               6  ...  デクラレーションオブウォー
# 8                良          13               6  ...    マインドユアビスケッツ
# 9                良          13               7  ...        トゥザワールド
# 10               良          13               7  ...        コパノリッキー
# 11               良          13               8  ...         ラブリーデイ
# 12               良          13               8  ...             ラニ
#
#        mother_name sex age weight_carried  jockey  stable horse_weight  \
# 0          Behkara   牡   5           56.0    仲原大生  大井佐々木洋          457
# 1        ポップコーンジャズ   牡   5           55.0    中山遥人  大井須田和伸          462
# 2    Tell a Secret   牝   7           54.0    石川駿介  大井岡野尚光          491
# 3       Tempo West   牝   5           54.0    矢野貴之  大井藤田輝信          510
# 4         タニノクリスタル   セ   7           55.0    谷内貫太  大井久保杉隆          479
# 5   Sweet Minister   牡   5           56.0     鷹見陸   大井澤佳宏          485
# 6      Wild Vision   牡   7           56.0     吉井章   大井市村誠          475
# 7       Tempo West   牝   4           54.0    横川怜央  大井久保杉隆          461
# 8         Jazzmane   牡   5           56.0    瀬川将輝  大井栗田裕光          533
# 9        トゥザヴィクトリー   牡   6           53.0    杉山海波  大井井上弘之          451
# 10         コパノニキータ   セ   7           56.0     野畑凌   大井鷹見浩          479
# 11       ポップコーンジャズ   牡   6           56.0    菅原涼太  大井荒井朋弘          451
# 12       ヘヴンリーロマンス   牝   7           54.0    澤田龍哉  大井田中正人          453
#
#    weight_diff    horse_id
# 0           -2  2021103462
# 1           -6  2021104202
# 2           -7  2019101304
# 3            2  2021102429
# 4           -4  2019109083
# 5           -3  2021102897
# 6           -1  2019101552
# 7           -1  2022109083
# 8           -3  2021106391
# 9            1  2020106112
# 10          -2  2019102067
# 11          -6  2020102455
# 12          -8  2019109031
#
# [13 rows x 22 columns], histories=        horse_id horse_name        date course weather  race_number  \
# 0     2021103462     ブッコワース  2026/03/24     大井       晴            1
# 1     2021103462     ブッコワース  2026/03/10     大井       雨            1
# 2     2021103462     ブッコワース  2025/11/10     大井       晴            2
# 3     2021103462     ブッコワース  2025/10/20     大井       曇            6
# 4     2021103462     ブッコワース  2025/10/05     大井       晴            4
# ...          ...        ...         ...    ...     ...          ...
# 3365  2022105174      フェアゴー  2025/06/14   3東京3       曇            7
# 3366  2022105174      フェアゴー  2025/05/17   2東京7       雨            2
# 3367  2022105174      フェアゴー  2025/03/23   2中京4       晴            3
# 3368  2022105174      フェアゴー  2025/02/23   1東京8       晴            1
# 3369  2022105174      フェアゴー  2024/12/07   4中京3       曇            5
#
#            race_name  num_horses  bracket_number  horse_number  ...  distance  \
# 0               C3五六          13               1             1  ...    1600.0
# 1               C3五六          14               4             6  ...    1600.0
# 2             C21819          13               7            11  ...    1600.0
# 3     住まいのみやこすぎな(C2)          10               7             8  ...    1600.0
# 4      ゴッドファーザー賞(C2)           8               4             4  ...    1600.0
# ...              ...         ...             ...           ...  ...       ...
# 3365           3歳未勝利          16               5             9  ...    1600.0
# 3366           3歳未勝利          16               8            16  ...    1600.0
# 3367           3歳未勝利          16               4             7  ...    1400.0
# 3368           3歳未勝利          16               5             9  ...    1400.0
# 3369            2歳新馬          16               4             8  ...    1400.0
#
#       track_condition   time margin  passing_order last_3f  horse_weight  \
# 0                   良  105.8    0.5        7-7-8-8    39.8         457.0
# 1                   稍  107.8    1.5        5-5-5-6    41.8         459.0
# 2                   稍  106.7    4.2        6-7-7-9    43.7         457.0
# 3                   稍  105.6    1.5        2-2-3-3    40.6         454.0
# 4                   良  104.3    0.8        5-5-5-5    40.9         452.0
# ...               ...    ...    ...            ...     ...           ...
# 3365                良   98.0    0.2            5-4    37.0         500.0
# 3366                稍   98.9    0.2            5-5    37.2         508.0
# 3367                良   86.2    0.8            9-9    38.0         500.0
# 3368                良   86.8    0.4          15-14    36.6         506.0
# 3369                良   87.2    2.0          16-16    36.6         502.0
#
#      weight_diff  winner_name  prize
# 0           -2.0    ワールドフォンテン    NaN
# 1            2.0    ワールドフォンテン    NaN
# 2            3.0     テンシノトリブン    NaN
# 3            2.0     ドラゴンバスター   10.0
# 4            0.0      フェアクラウド   10.0
# ...          ...          ...    ...
# 3365        -8.0    ブラーブデシジョン  220.0
# 3366         8.0      クリオシダード  220.0
# 3367        -6.0    ハウリングウィンド   84.0
# 3368         4.0    プライベートアイズ   84.0
# 3369         0.0         トゥロン    NaN
#
# [3370 rows x 26 columns])]

# %%
# RaceInfo 作成
from src.services.race_factory import RaceInfoFactory

factory = RaceInfoFactory()

# %% [markdown]
# # Simulatorの個別テスト

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.constants.course_master import CourseSpec, NAME_TO_COURSE

name = "大井"
NAME_TO_COURSE.get(name, "")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# CourseSpec(name='大井', is_jra=False, is_excluded=False, track_width=25, corner_penalty=0.15, furf_friction=0.01, surface_friction=0.05)

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.constants.course_master import COURSE_MASTER, NAME_TO_CODE

b = "大井"
a = NAME_TO_CODE[b]
print(a)
# Out:
# 44

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.constants.race_master import TrackCondition, TrackWeather

a = 0.1
res = TrackCondition.from_str(a)
res2 = TrackWeather.from_str(a)
res, res2
# Out:
# (<TrackCondition.ANY: '未'>, <TrackWeather.ANY: '未'>)

# %%
# 開発中のコード変更を自動反映させる設定
# %reload_ext autoreload
# %autoreload 2

from src.core.simulator import RaceSimulator

sim = RaceSimulator()
date = "20260324"
courses = ["大井",]
race_numbers = [1,]
#sim._prepare_races(date, courses, race_numbers)
sim.run(date, courses, race_numbers)
# Out:
# True
